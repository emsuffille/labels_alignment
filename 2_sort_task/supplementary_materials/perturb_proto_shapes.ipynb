# %%
import numpy as np
from scipy.interpolate import splprep, splev
import matplotlib.pyplot as plt
from pylab import rcParams
from PIL import Image, ImageDraw
rcParams['figure.figsize'] = 5.01, 5.15

#Here is a script for generating protoptype shapes (experiment 1) and then adding noise to produce other shapes with category resemblance.

# %%
#Coords for prototype A
pts = np.array([[ 6.55525 ,  2.55472 ],
   [ 6.17284 ,  2.802609],
   [ 5.53946 ,  2.649209],
   [ 4.93053 ,  2.444444],
   [ 4.32544 ,  2.318749],
   [ 3.90982 ,  2.2875  ],
   [ 3.51294 ,  2.221875],
   [ 3.09107 ,  2.29375 ],
   [ 2.64013 ,  2.4375  ],
   [ 2.275444,  2.653124],
   [ 2.137945,  3.26562 ],
   [ 2.15982 ,  3.84375 ],
   [ 2.20982 ,  4.31562 ],
   [ 2.334704,  4.87873 ],
   [ 2.314264,  5.5047  ],
   [ 2.311709,  5.9135  ],
   [ 2.29638 ,  6.42961 ],
   [ 2.619374,  8 ],
   [ 3.32448 ,  8.353 ],
   [ 3.31582 ,  5.68866 ],
   [ 4.33527 ,  5.33862 ],
   [ 3.95968 ,  5.61967 ],
   [ 3.56366 ,  5.73976 ],
   [ 3.78818 ,  6.55292 ],
   [ 4.27712 ,  6.8283  ],
   [ 4.89532 ,  6.78615 ],
   [ 5.35334 ,  6.72433 ],
   [ 5.71583 ,  6.54449 ],
   [ 6.13452 ,  6.46019 ],
   [ 6.54478 ,  6.26068 ],
   [ 6.7873  ,  5.74615 ],
   [ 6.64086 ,  5.25269 ],
   [ 6.45649 ,  4.86206 ],
   [ 6.41586 ,  4.46519 ],
   [ 5.34086 ,  3.43394 ],
   [ 5.76392 ,  3.55156 ],
   [ 7.37056 ,  3.8778  ],
    [ 7.53116 ,  2.47228 ],
   [ 7.53116 ,  2.47228 ]])

# %%
#print prototype A
#generate splines
tck, u = splprep(pts.T, s=0.0, per=3) # s-parameter controls roundness 

#interpolate
u_new = np.linspace(u.min(), u.max(), 1000)
x_new, y_new = splev(u_new, tck, der=0)


#plt.plot(pts[:,0], pts[:,1], 'ro') #uncomment to show points
plt.plot(x_new, y_new, 'b--')
plt.show()
# Out:
# /Users/ellisesuffill/Desktop/anaconda3/lib/python3.7/site-packages/scipy/interpolate/_fitpack_impl.py:227: RuntimeWarning: Setting x[0][39]=x[0][0]
#
#   (i, m, i)))
#
# /Users/ellisesuffill/Desktop/anaconda3/lib/python3.7/site-packages/scipy/interpolate/_fitpack_impl.py:227: RuntimeWarning: Setting x[1][39]=x[1][0]
#
#   (i, m, i)))

# %%
#include some random Gaussian noise 
#the Gaussian noise is added at 3 different levels of range (i.e., low, medium, high distortion)
#so if you like a shape and want to use it, also record the 'scale=' used to generate it!
countx=0
for x in np.nditer(pts[:,0], op_flags=['readwrite']):
    countx+=1
    if countx % 5==0:
        x[...]+=np.random.normal(scale=.48)
    else:
        x=x
    #print(x)

county=0
for y in np.nditer(pts[:,0], op_flags=['readwrite']):
    county+=1
    if county % 5==0:
        y[...]+=np.random.normal(scale=.48)
    else:
        y=y
    #print(y)

#generate splines
tck, u = splprep(pts.T, s=0, per=3) # s-parameter controls roundness 

#interpolate
u_new = np.linspace(u.min(), u.max(), 1000)
x_new, y_new = splev(u_new, tck, der=0)


#plt.plot(pts[:,0], pts[:,1], 'ro') #uncomment to show points
plt.plot(x_new, y_new, 'black')
plt.axis('off')

#saves to same cd as file so saving to desktop atm!
#make sure you change .png name so as not to overwrite good shapes!
fig1 = plt.gcf()
fig1.savefig('A_xx.png', dpi=98, bbox_inches='tight')
plt.show()

# %%
#Coords for prototype B
pts2 = np.array([[ 5.55525 ,  3.05472 ],
   [ 5.17284 ,  2.802609],
   [ 7 ,  0.7],
    [ 5 ,  0.25],
   [ 4 ,  0.7],
   [ 4.32544 ,  2.318749],
   [ 3.90982 ,  2.2875  ],
   [ 3.51294 ,  2.221875],
   [ 3.09107 ,  2.29375 ],
   [ 2 ,  2  ],
   [ 1.275444,  1],
    [-0.475444,  1],
    [-0.6,  1],
    [-0.7,  3],
   [ 1.137945,  3.26562 ],
   [ 3.15982 ,  3.84375 ],
   [ 2.20982 ,  4.31562 ],
   [ 2.334704,  4.87873 ],
   [ 2.314264,  5.5047  ],
   [ 2.311709,  5.9135  ],
   [ 2.29638 ,  6.42961 ],
   [ 2.619374,  6.75021 ],
   [ 3.32448 ,  7.353 ],
   [ 3.31582 ,  7.7 ],
   [ 3.35159 ,  8 ],
   [ 3.78818 ,  8 ],
   [ 4.27712 ,  8.2 ],
   [ 4.89532 ,  8.5 ],
   [ 5.35334 ,  8 ],
   [ 5.71583 ,  6.54449 ],
   [ 6.13452 ,  6.46019 ],
   [ 6.54478 ,  6.26068 ],
   [ 6.7873  ,  5.74615 ],
   [ 6.64086 ,  5.25269 ],
   [ 6.45649 ,  4.86206 ],
   [ 6.47649 ,  4.86206 ],
   [ 6.41586 ,  4.46519 ],
   [ 6.43586 ,  4.46519 ],
   [ 5.44711 ,  4.26519 ]])

# %%
#print prototype B
#generate splines
tck, u = splprep(pts2.T, s=0.0, per=3) # s-parameter controls roundness 

#interpolate
u_new = np.linspace(u.min(), u.max(), 1000)
x_new, y_new = splev(u_new, tck, der=0)


#plt.plot(pts[:,0], pts[:,1], 'ro') #uncomment to show points
plt.plot(x_new, y_new, 'b--')
plt.show()
# Out:
# /Users/ellisesuffill/Desktop/anaconda3/lib/python3.7/site-packages/scipy/interpolate/_fitpack_impl.py:227: RuntimeWarning: Setting x[0][39]=x[0][0]
#
#   (i, m, i)))
#
# /Users/ellisesuffill/Desktop/anaconda3/lib/python3.7/site-packages/scipy/interpolate/_fitpack_impl.py:227: RuntimeWarning: Setting x[1][39]=x[1][0]
#
#   (i, m, i)))

# %%
#include some random Gaussian noise 
#the Gaussian noise is added at 3 different levels of range (i.e., low, medium, high distortion)
#so if you like a shape and want to use it, also record the 'scale=' used to generate it!
countx=0
for x in np.nditer(pts2[:,0], op_flags=['readwrite']):
    countx+=1
    if countx % 5==0:
        x[...]+=np.random.normal(scale=.48)
    else:
        x=x
    #print(x)

county=0
for y in np.nditer(pts2[:,0], op_flags=['readwrite']):
    county+=1
    if county % 5==0:
        y[...]+=np.random.normal(scale=.48)
    else:
        y=y
    #print(y)

#generate splines
tck, u = splprep(pts2.T, s=0, per=3) # s-parameter controls roundness 

#interpolate
u_new = np.linspace(u.min(), u.max(), 1000)
x_new, y_new = splev(u_new, tck, der=0)


#plt.plot(pts[:,0], pts[:,1], 'ro') #uncomment to show points
plt.plot(x_new, y_new, 'black')
plt.axis('off')

#saves to same cd as file so saving to desktop atm!
#make sure you change .png name so as not to overwrite good shapes!
fig1 = plt.gcf()
fig1.savefig('B_xx.png', dpi=98, bbox_inches='tight')
plt.show()
